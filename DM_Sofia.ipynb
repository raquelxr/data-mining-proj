# %% [markdown]
# # Costumer Segmentation:

# %% [markdown]
# ## Import libraries/data:

# %%
import pandas as pd
import datetime as dt
import numpy as np

# %%
data = pd.read_csv('XYZ_sports_dataset.csv', sep =';')

# %% [markdown]
# ## Data Exploration:

# %% [markdown]
# #### ID:

# %%
data['ID'].value_counts()
# Out:
# ID
# 10000    1
# 19966    1
# 19954    1
# 19955    1
# 19956    1
#         ..
# 14984    1
# 14985    1
# 14986    1
# 14987    1
# 24941    1
# Name: count, Length: 14942, dtype: int64

# %% [markdown]
# All id's are unique so we can set it as an index:

# %%
data.set_index('ID', inplace=True)

# %%
#We have one duplicated client when we set index as ID, so we remove it
data.drop_duplicates(inplace=True)

# %%
teste = data.copy()

# %% [markdown]
# #### Age:

# %%
data['Age'].unique()
# Out:
# array([60, 29, 23,  9, 35, 24, 14, 20, 63, 12, 28, 26, 47, 39, 19, 30, 43,
#        44, 13, 17, 22, 21,  2,  1, 74, 38, 46, 34,  6, 11, 42, 56, 33, 52,
#        54, 32,  7, 27,  3, 37, 31, 49, 57, 15,  8, 83,  5, 53, 40, 41, 45,
#        18, 64, 51, 25, 69, 55, 48, 16, 10, 72, 62, 36,  4, 78, 50, 67, 66,
#        59, 86, 81, 73, 65,  0, 68, 80, 58, 76, 85, 61, 75, 82, 71, 70, 79,
#        77, 84, 87])

# %% [markdown]
# There are no wierd values for age

# %% [markdown]
# #### Income:

# %% [markdown]
# Children under 16 should have no income:

# %%
data[data['Age']<16][data['Income']!=0]
# Out:
# /var/folders/x6/c7bgz3zn0hg_kdmljrfw7k_m0000gn/T/ipykernel_11507/702331251.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['Age']<16][data['Income']!=0]
#        Age  Gender  Income EnrollmentStart EnrollmentFinish LastPeriodStart  \
# ID
# 10076    9    Male     NaN      2017-09-16       2017-09-16      2019-07-01
# 10224    7    Male     NaN      2016-04-20       2018-11-11      2018-07-01
# 10226   10  Female     NaN      2016-11-14       2016-11-14      2019-07-01
# 10261    3    Male     NaN      2017-09-07       2017-09-07      2019-07-01
# 10295    5  Female     NaN      2015-03-05       2015-03-05      2019-07-01
# ...    ...     ...     ...             ...              ...             ...
# 24804    4  Female     NaN      2016-03-05       2016-03-05      2019-07-01
# 24830    2    Male  2750.0      2018-07-26       2018-07-26      2019-07-01
# 24836    5    Male     NaN      2018-07-02       2018-07-02      2019-07-01
# 24874   15    Male     NaN      2015-11-02       2016-07-31      2016-01-01
# 24930    4    Male     NaN      2017-06-30       2017-11-07      2017-07-01
#
#       LastPeriodFinish DateLastVisit  DaysWithoutFrequency  LifetimeValue  \
# ID
# 10076       2019-12-31    2019-10-26                     5         708.20
# 10224       2018-12-31    2018-10-25                    17         836.60
# 10226       2019-12-31    2019-10-26                     5        1331.55
# 10261       2019-12-31    2019-10-19                    12        1066.40
# 10295       2019-12-31    2019-09-07                    54         286.30
# ...                ...           ...                   ...            ...
# 24804       2019-12-31    2019-10-26                     5        1656.30
# 24830       2019-12-31    2019-10-19                    12         773.32
# 24836       2019-12-31    2019-10-30                     1         654.60
# 24874       2016-12-31    2016-05-30                    62         353.60
# 24930       2017-12-31    2017-09-30                    38          77.60
#
#        ...  OtherActivities  NumberOfFrequencies  AttendedClasses  \
# ID     ...
# 10076  ...              0.0                 64.0               64
# 10224  ...              0.0                107.0               91
# 10226  ...              0.0                 65.0               47
# 10261  ...              0.0                 78.0               62
# 10295  ...              0.0                 15.0                7
# ...    ...              ...                  ...              ...
# 24804  ...              0.0                 95.0               88
# 24830  ...              0.0                 27.0               20
# 24836  ...              0.0                 20.0               20
# 24874  ...              0.0                 20.0               17
# 24930  ...              0.0                  5.0                5
#
#        AllowedWeeklyVisitsBySLA  AllowedNumberOfVisitsBySLA  \
# ID
# 10076                       2.0                       17.42
# 10224                       2.0                       11.72
# 10226                       1.0                        8.71
# 10261                       2.0                       17.42
# 10295                       1.0                        3.14
# ...                         ...                         ...
# 24804                       2.0                        9.72
# 24830                       2.0                       17.42
# 24836                       2.0                       15.42
# 24874                       1.0                        8.71
# 24930                       2.0                       17.42
#
#        RealNumberOfVisits  NumberOfRenewals  HasReferences  \
# ID
# 10076                   6                 2            0.0
# 10224                   6                 3            0.0
# 10226                   4                 3            0.0
# 10261                   5                 2            0.0
# 10295                   0                 5            0.0
# ...                   ...               ...            ...
# 24804                   3                 4            0.0
# 24830                   8                 2            0.0
# 24836                   9                 2            0.0
# 24874                   0                 0            0.0
# 24930                   7                 1            0.0
#
#        NumberOfReferences  Dropout
# ID
# 10076                   0        0
# 10224                   0        1
# 10226                   0        0
# 10261                   0        0
# 10295                   0        0
# ...                   ...      ...
# 24804                   0        0
# 24830                   0        0
# 24836                   0        0
# 24874                   0        1
# 24930                   0        1
#
# [360 rows x 30 columns]

# %%
data.loc[data["Age"] < 16 , "Income"] = 0

# %% [markdown]
# #### Gender:

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# No wierd values for Gender

# %% [markdown]
# #### EnrollmentStart / EnrollmentFinish

# %% [markdown]
# We start by turning all dates into datetime format:

# %%
data['EnrollmentStart'] = pd.to_datetime(data['EnrollmentStart'])
data['EnrollmentFinish'] = pd.to_datetime(data['EnrollmentFinish'])

data['LastPeriodStart'] = pd.to_datetime(data['LastPeriodStart'])
data['LastPeriodFinish'] = pd.to_datetime(data['LastPeriodFinish'])

data['DateLastVisit'] = pd.to_datetime(data['DateLastVisit'])

# %%
data[data['EnrollmentStart'] == data['EnrollmentFinish']]['LastPeriodFinish'].value_counts()
# Out:
# LastPeriodFinish
# 2019-12-31    2038
# 2019-06-30     186
# 2018-12-31     117
# 2017-12-31      22
# 2016-12-31      20
# 2018-06-30      20
# 2017-06-30       9
# 2016-06-30       5
# 2015-06-30       3
# 2015-12-31       2
# Name: count, dtype: int64

# %% [markdown]
# Most People have LastPeriodFinish = '2019-12-31' (as expected for renovating members), so we'll look into the other cases:

# %% [markdown]
# ##### Members who have not been active in Current Period:

# %% [markdown]
# We'll check the case of people who haven't visited the Facility since the last Period:

# %%
data.loc[data['DateLastVisit']< '2019-06-30', 'Dropout'].value_counts()
# Out:
# Dropout
# 1    11335
# 0      324
# Name: count, dtype: int64

# %% [markdown]
# The people who had DateLastVisit < '2019-06-30' and don't have a DropOut are the poeple who have 'EnrollmentStart'= 'EnrolmentFinish', which tells us that:
# - these people have dropped out but that has not been added to the system.
# - Their contract is still active as they've been paying, but not comming to the gym.

# %%
data[data['EnrollmentStart'] == data['EnrollmentFinish']].loc[data['DateLastVisit']< '2019-06-30']
# Out:
#        Age  Gender  Income EnrollmentStart EnrollmentFinish LastPeriodStart  \
# ID
# 10111   24    Male  2250.0      2015-04-30       2015-04-30      2015-01-01
# 10185   20    Male  1390.0      2017-09-08       2017-09-08      2019-01-01
# 10244    7    Male     0.0      2018-04-07       2018-04-07      2018-07-01
# 10363   19  Female  1290.0      2018-04-05       2018-04-05      2019-01-01
# 10438   23  Female  1940.0      2015-01-21       2015-01-21      2019-07-01
# ...    ...     ...     ...             ...              ...             ...
# 24700   10  Female     0.0      2016-01-04       2016-01-04      2016-01-01
# 24756   21  Female  1660.0      2018-10-11       2018-10-11      2019-01-01
# 24781   17  Female  1270.0      2019-02-12       2019-02-12      2019-07-01
# 24871   32    Male  4610.0      2018-04-05       2018-04-05      2018-01-01
# 24883   24  Female  2120.0      2016-09-13       2016-09-13      2018-01-01
#
#       LastPeriodFinish DateLastVisit  DaysWithoutFrequency  LifetimeValue  \
# ID
# 10111       2015-06-30    2015-05-12                  1633          33.60
# 10185       2019-06-30    2019-04-03                   211         281.00
# 10244       2019-06-30    2019-02-02                   271         131.80
# 10363       2019-06-30    2019-03-29                   216         258.20
# 10438       2019-12-31    2018-04-07                   572         693.15
# ...                ...           ...                   ...            ...
# 24700       2016-12-31    2016-07-04                  1214         699.55
# 24756       2019-06-30    2019-05-28                   156         115.30
# 24781       2019-12-31    2019-04-29                   185         156.50
# 24871       2018-12-31    2018-05-18                   531         147.35
# 24883       2018-12-31    2018-07-27                   461         533.20
#
#        ...  OtherActivities  NumberOfFrequencies  AttendedClasses  \
# ID     ...
# 10111  ...              0.0                  2.0                0
# 10185  ...              0.0                 72.0                0
# 10244  ...              0.0                  7.0                7
# 10363  ...              0.0                 44.0                0
# 10438  ...              0.0                109.0                0
# ...    ...              ...                  ...              ...
# 24700  ...              0.0                 21.0               20
# 24756  ...              0.0                 21.0               19
# 24781  ...              0.0                  7.0                0
# 24871  ...              0.0                 11.0                0
# 24883  ...              0.0                100.0                0
#
#        AllowedWeeklyVisitsBySLA  AllowedNumberOfVisitsBySLA  \
# ID
# 10111                       7.0                       28.98
# 10185                       7.0                       38.01
# 10244                       1.0                        8.86
# 10363                       7.0                       59.01
# 10438                       7.0                       24.01
# ...                         ...                         ...
# 24700                       4.0                       34.84
# 24756                       1.0                        8.71
# 24781                       7.0                       21.98
# 24871                       7.0                       60.97
# 24883                       7.0                       60.97
#
#        RealNumberOfVisits  NumberOfRenewals  HasReferences  \
# ID
# 10111                   2                 5            0.0
# 10185                   9                 2            0.0
# 10244                   3                 2            0.0
# 10363                   7                 2            0.0
# 10438                   0                 5            0.0
# ...                   ...               ...            ...
# 24700                   5                 4            0.0
# 24756                  10                 1            0.0
# 24781                   0                 1            0.0
# 24871                   0                 2            0.0
# 24883                   6                 3            0.0
#
#        NumberOfReferences  Dropout
# ID
# 10111                   0        0
# 10185                   0        0
# 10244                   0        0
# 10363                   0        0
# 10438                   0        0
# ...                   ...      ...
# 24700                   0        0
# 24756                   0        0
# 24781                   0        0
# 24871                   0        0
# 24883                   0        0
#
# [324 rows x 30 columns]

# %% [markdown]
# Some people have DateLastVisit in their LastPeriod (233):
# - Those people will be considered the ones who Droped Out - EnrollmentFinished on the date of LastVisit.
# - The rest will be considered active.

# %%
data[data['EnrollmentStart'] == data['EnrollmentFinish']][data['DateLastVisit']< data['LastPeriodFinish']][data['DateLastVisit']> data['LastPeriodStart']][data['DateLastVisit']< '2019-06-30']
# Out:
# /var/folders/x6/c7bgz3zn0hg_kdmljrfw7k_m0000gn/T/ipykernel_11507/2181809022.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['EnrollmentStart'] == data['EnrollmentFinish']][data['DateLastVisit']< data['LastPeriodFinish']][data['DateLastVisit']> data['LastPeriodStart']][data['DateLastVisit']< '2019-06-30']
# /var/folders/x6/c7bgz3zn0hg_kdmljrfw7k_m0000gn/T/ipykernel_11507/2181809022.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['EnrollmentStart'] == data['EnrollmentFinish']][data['DateLastVisit']< data['LastPeriodFinish']][data['DateLastVisit']> data['LastPeriodStart']][data['DateLastVisit']< '2019-06-30']
# /var/folders/x6/c7bgz3zn0hg_kdmljrfw7k_m0000gn/T/ipykernel_11507/2181809022.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['EnrollmentStart'] == data['EnrollmentFinish']][data['DateLastVisit']< data['LastPeriodFinish']][data['DateLastVisit']> data['LastPeriodStart']][data['DateLastVisit']< '2019-06-30']
#        Age  Gender  Income EnrollmentStart EnrollmentFinish LastPeriodStart  \
# ID
# 10111   24    Male  2250.0      2015-04-30       2015-04-30      2015-01-01
# 10185   20    Male  1390.0      2017-09-08       2017-09-08      2019-01-01
# 10244    7    Male     0.0      2018-04-07       2018-04-07      2018-07-01
# 10363   19  Female  1290.0      2018-04-05       2018-04-05      2019-01-01
# 10490   60    Male  5760.0      2016-10-17       2016-10-17      2019-01-01
# ...    ...     ...     ...             ...              ...             ...
# 24684   59    Male  7240.0      2017-01-02       2017-01-02      2019-01-01
# 24700   10  Female     0.0      2016-01-04       2016-01-04      2016-01-01
# 24756   21  Female  1660.0      2018-10-11       2018-10-11      2019-01-01
# 24871   32    Male  4610.0      2018-04-05       2018-04-05      2018-01-01
# 24883   24  Female  2120.0      2016-09-13       2016-09-13      2018-01-01
#
#       LastPeriodFinish DateLastVisit  DaysWithoutFrequency  LifetimeValue  \
# ID
# 10111       2015-06-30    2015-05-12                  1633          33.60
# 10185       2019-06-30    2019-04-03                   211         281.00
# 10244       2019-06-30    2019-02-02                   271         131.80
# 10363       2019-06-30    2019-03-29                   216         258.20
# 10490       2019-06-30    2019-03-06                   239         647.89
# ...                ...           ...                   ...            ...
# 24684       2019-06-30    2019-05-24                   160         897.10
# 24700       2016-12-31    2016-07-04                  1214         699.55
# 24756       2019-06-30    2019-05-28                   156         115.30
# 24871       2018-12-31    2018-05-18                   531         147.35
# 24883       2018-12-31    2018-07-27                   461         533.20
#
#        ...  OtherActivities  NumberOfFrequencies  AttendedClasses  \
# ID     ...
# 10111  ...              0.0                  2.0                0
# 10185  ...              0.0                 72.0                0
# 10244  ...              0.0                  7.0                7
# 10363  ...              0.0                 44.0                0
# 10490  ...              0.0                212.0                0
# ...    ...              ...                  ...              ...
# 24684  ...              0.0                155.0                0
# 24700  ...              0.0                 21.0               20
# 24756  ...              0.0                 21.0               19
# 24871  ...              0.0                 11.0                0
# 24883  ...              0.0                100.0                0
#
#        AllowedWeeklyVisitsBySLA  AllowedNumberOfVisitsBySLA  \
# ID
# 10111                       7.0                       28.98
# 10185                       7.0                       38.01
# 10244                       1.0                        8.86
# 10363                       7.0                       59.01
# 10490                       7.0                       41.02
# ...                         ...                         ...
# 24684                       7.0                       60.97
# 24700                       4.0                       34.84
# 24756                       1.0                        8.71
# 24871                       7.0                       60.97
# 24883                       7.0                       60.97
#
#        RealNumberOfVisits  NumberOfRenewals  HasReferences  \
# ID
# 10111                   2                 5            0.0
# 10185                   9                 2            0.0
# 10244                   3                 2            0.0
# 10363                   7                 2            0.0
# 10490                   0                 3            0.0
# ...                   ...               ...            ...
# 24684                   5                 3            0.0
# 24700                   5                 4            0.0
# 24756                  10                 1            0.0
# 24871                   0                 2            0.0
# 24883                   6                 3            0.0
#
#        NumberOfReferences  Dropout
# ID
# 10111                   0        0
# 10185                   0        0
# 10244                   0        0
# 10363                   0        0
# 10490                   0        0
# ...                   ...      ...
# 24684                   0        0
# 24700                   0        0
# 24756                   0        0
# 24871                   0        0
# 24883                   0        0
#
# [233 rows x 30 columns]

# %%
index_i =[]
index_drop = []
for i in data.index:
    start = data['LastPeriodStart'][i]
    end = data['LastPeriodFinish'][i]
    date_visit= data['DateLastVisit'][i]
    if data['EnrollmentFinish'][i] == data['EnrollmentStart'][i]:
        if start<=date_visit <=end:
            if data['DateLastVisit'][i] < pd.Timestamp(dt.date(2019,6,30)):
                index_i.append(i)

# %% [markdown]
# These people are the Drop Outs:

# %%
data.loc[index_i, 'Dropout']=1

# %%
data.loc[index_i, 'EnrollmentFinish'] = data.loc[index_i, 'DateLastVisit']

# %% [markdown]
# -----

# %% [markdown]
# We now need to check our non-drop out members:

# %%
data[data['EnrollmentStart'] == data['EnrollmentFinish']][data['DateLastVisit']< '2019-06-30']['LastPeriodFinish'].value_counts()
# Out:
# /var/folders/x6/c7bgz3zn0hg_kdmljrfw7k_m0000gn/T/ipykernel_11507/3967296023.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['EnrollmentStart'] == data['EnrollmentFinish']][data['DateLastVisit']< '2019-06-30']['LastPeriodFinish'].value_counts()
# LastPeriodFinish
# 2019-12-31    81
# 2019-06-30     4
# 2018-12-31     4
# 2016-12-31     1
# 2018-06-30     1
# Name: count, dtype: int64

# %% [markdown]
# Members that don't have LastPeriodFinish == '2019-12-31' will be removed (it should be '2019-12-31' so they'll be considered errors):

# %%
data.drop(data[data['EnrollmentStart'] == data['EnrollmentFinish']][data['DateLastVisit']< '2019-06-30'][data['LastPeriodFinish']!= '2019-12-31'].index, inplace = True)
# Out:
# /var/folders/x6/c7bgz3zn0hg_kdmljrfw7k_m0000gn/T/ipykernel_11507/3883782199.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data.drop(data[data['EnrollmentStart'] == data['EnrollmentFinish']][data['DateLastVisit']< '2019-06-30'][data['LastPeriodFinish']!= '2019-12-31'].index, inplace = True)
# /var/folders/x6/c7bgz3zn0hg_kdmljrfw7k_m0000gn/T/ipykernel_11507/3883782199.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data.drop(data[data['EnrollmentStart'] == data['EnrollmentFinish']][data['DateLastVisit']< '2019-06-30'][data['LastPeriodFinish']!= '2019-12-31'].index, inplace = True)

# %% [markdown]
# ##### Had activity in last period + paying members:

# %% [markdown]
# The rest of the people are the ones who have activity in the gym in the last period/ are still paying, so we'll make:
# - 'EnrollmentFinish' == '2019-10-31'
# - 'LastPeriodFinish' == '2019-12-31'

# %%
sum = 0
index_i =[]
for i in data.index:
    date_visit= data['DateLastVisit'][i]
    if data['EnrollmentFinish'][i] == data['EnrollmentStart'][i]:
        index_i.append(i)

# %%
data.loc[index_i, 'LastPeriodFinish']='2019-12-31'

# %%
data.loc[index_i, 'EnrollmentFinish']= '2019-10-31'

# %% [markdown]
# All our Dates should now make some kind of sense.

# %% [markdown]
# ------

# %% [markdown]
# Create a new variable called 'Contract Duration' in days:

# %%
data['Contract_Duration'] = (data['EnrollmentFinish']- data['EnrollmentStart'])
data['Contract_Duration']=data['Contract_Duration'].dt.days

# %% [markdown]
# #### LastPeriodStart/Finish

# %% [markdown]
# Create a new Variable called 'Active_Period' in days:

# %%
data['Active_Period'] = (data['LastPeriodFinish']- data['LastPeriodStart'])
data['Active_Period']=data['Active_Period'].dt.days

# %%
data['Active_Period'].value_counts()
# Out:
# Active_Period
# 183     5132
# 364     3834
# 180     3504
# 365     1551
# 181      752
# 546       57
# 729       50
# 548       29
# 1094      10
# 913        7
# 1460       3
# 1278       2
# Name: count, dtype: int64

# %% [markdown]
# #### DateLastVisit

# %% [markdown]
# We need to check how many people don't have Period that matches:
# - DateLastVisit
# - EnrollmentFinish-2

# %%
from dateutil.relativedelta import relativedelta

sum = 0
index_i =[]
for i in data.index:
    start = data['LastPeriodStart'][i]
    end = data['LastPeriodFinish'][i]
    date_test = data['EnrollmentFinish'][i] - relativedelta(months=2)
    date_visit= data['DateLastVisit'][i]
    if start<=date_test <=end:
        sum = sum
    elif start<=date_visit <=end:
        sum = sum
    else:
        sum+=1
        index_i.append(i)
print(sum)
# Out:
# 150

# %% [markdown]
# We can drop all these people:

# %%
data.drop(index_i, inplace = True)

# %% [markdown]
# ### DaysWithoutFrequency
